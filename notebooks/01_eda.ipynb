# %% [markdown]
# # 01 — Exploratory Data Analysis (Phase 1)
#
# First look at **UNSW-NB15** (source, 2015) and **TON_IoT Network** (target, ~2019–2020).
#
# Goals: shapes, dtypes, class balance (`label` + multiclass), per-column null/`-` counts, value
# ranges, and a **side-by-side schema catalogue** that drives the Phase 2 feature alignment.
# Save summary tables to `reports/`.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))  # import the src package

import numpy as np
import pandas as pd

from src.config import UNSW_TRAIN_CSV, UNSW_TEST_CSV, TONIOT_CSV, set_seeds

set_seeds()

# TODO Phase 1: load the raw CSVs (see data/README.md for download instructions)
# unsw_train = pd.read_csv(UNSW_TRAIN_CSV)
# toniot = pd.read_csv(TONIOT_CSV)

# %%
# TODO Phase 1: shapes, dtypes, class balance for label + multiclass column
# TODO Phase 1: per-column null / '-' counts, value ranges
# TODO Phase 1: side-by-side schema catalogue (column, dtype, one-line meaning) -> reports/
